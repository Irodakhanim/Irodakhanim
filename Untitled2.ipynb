# %%
#download vital python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read the data from the csv file
gender = pd.read_csv("https://raw.githubusercontent.com/Irodakhanim/Irodakhanim/main/gender-gap-in-primary-education.csv", delimiter=";")
gender
# Out:
#      Entity,Code,Year,"Primary education, pupils (% female)"
# 0                         Afghanistan,AFG,1970,14.08269
# 1                         Afghanistan,AFG,1971,13.74349
# 2                         Afghanistan,AFG,1972,14.00464
# 3                         Afghanistan,AFG,1973,14.54673
# 4                         Afghanistan,AFG,1974,14.44661
# ...                                                 ...
# 9434                         Zimbabwe,ZWE,2001,49.20609
# 9435                         Zimbabwe,ZWE,2002,49.38101
# 9436                         Zimbabwe,ZWE,2003,49.47874
# 9437                         Zimbabwe,ZWE,2012,49.55658
# 9438                         Zimbabwe,ZWE,2013,49.50317
#
# [9439 rows x 1 columns]

# %%
gender = pd.read_csv("https://raw.githubusercontent.com/Irodakhanim/Irodakhanim/main/gender-ratios-for-mean-years-of-schooling.csv",delimiter=";")
gender
# Out:
#     Entity,Code,Year,Regional female to male years schooling (Lee-Lee (2016))
# 0                     Advanced Economies,,1870,74.4576
# 1                    Advanced Economies,,1875,76.92046
# 2                    Advanced Economies,,1880,74.92967
# 3                     Advanced Economies,,1885,78.5665
# 4                    Advanced Economies,,1890,77.19675
# ..                                                 ...
# 169                  Sub-Saharan Africa,,1990,67.36083
# 170                  Sub-Saharan Africa,,1995,72.22995
# 171                  Sub-Saharan Africa,,2000,74.32109
# 172                  Sub-Saharan Africa,,2005,77.87061
# 173                  Sub-Saharan Africa,,2010,81.99623
#
# [174 rows x 1 columns]

# %%
primary = pd.read_csv("https://raw.githubusercontent.com/Irodakhanim/Irodakhanim/main/primary-completion-rate-gender-parity-index.csv",delimiter=";")
primary
# Out:
#      Entity,Code,Year,"Primary completion rate, gender parity index (GPI)"
# 0                Afghanistan,AFG,1974,0.153280004858971
# 1              Afghanistan,AFG,1977,0.18531000614166301
# 2                Afghanistan,AFG,1978,0.196439996361732
# 3                Afghanistan,AFG,1980,0.211219996213913
# 4              Afghanistan,AFG,1981,0.24907000362873102
# ...                                                 ...
# 4641               Zimbabwe,ZWE,2001,0.9417399764060971
# 4642                Zimbabwe,ZWE,2002,0.955429971218109
# 4643                Zimbabwe,ZWE,2003,0.960979998111725
# 4644                 Zimbabwe,ZWE,2012,1.02572000026703
# 4645                 Zimbabwe,ZWE,2013,1.01522994041443
#
# [4646 rows x 1 columns]

# %%
#Can we see that from the given chart the total number of people aged 15+ with no education in millions by continent 1970-2050
import matplotlib.pyplot as plt

labels = 'Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America'
sizes = [108.5529022, 543.0627898, 38.40432161, 17.69630628, 0.435840983, 27.23616332]
explode = (0, 0.25, 0, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Asia')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
